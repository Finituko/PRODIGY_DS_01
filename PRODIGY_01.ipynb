# %% [markdown]
# # **Task 01**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\DELL\\Downloads\\API_SP.POP.TOTL_DS2_en_csv_v2_900.csv")
df1=pd.read_csv("C:\\Users\\DELL\\Downloads\\Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_900.csv")
#df2=pd.read_csv("C:\\Users\\DELL\\Downloads\\")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  265 non-null    object
#  1   Region        217 non-null    object
#  2   IncomeGroup   216 non-null    object
#  3   SpecialNotes  127 non-null    object
#  4   TableName     265 non-null    object
#  5   Unnamed: 5    0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 12.6+ KB

# %%
df1.drop(columns="Unnamed: 5", inplace=True)

# %%
df1.columns=df1.columns.str.replace("TableName", "Country Name")

# %%
df1.dropna()
# Out:
#     Country Code                      Region          IncomeGroup  \
# 2            AFG                  South Asia           Low income
# 4            AGO          Sub-Saharan Africa  Lower middle income
# 9            ARG   Latin America & Caribbean  Upper middle income
# 14           AUT       Europe & Central Asia          High income
# 16           BDI          Sub-Saharan Africa           Low income
# ..           ...                         ...                  ...
# 259          WSM         East Asia & Pacific  Lower middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  Country Name
# 2    The reporting period for national accounts dat...   Afghanistan
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df.dropna()
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54922.0      55578.0      56320.0      57002.0
# ...

# %%
width = 16
height = 8
plt.figure(figsize=(width, height))
plt.bar(df["Country Name"][10:17], df["1970"][10:17])

# set x/y labels and plot title
plt.xlabel("Country Names")
plt.ylabel("Population Total for the Year 1970")
plt.title("Chart of Random three Countries Population in the Year 1970 ")
# Out:
# Text(0.5, 1.0, 'Chart of Random three Countries Population in the Year 1970 ')

# %%
plot_df=df

# %%
plot_df.drop(["Indicator Name","Indicator Code","Country Code"], axis=1, inplace=True)

# %%
plot_df
# Out:
#                     Country Name         1960         1961         1962  \
# 0                          Aruba      54922.0      55578.0      56320.0
# 1    Africa Eastern and Southern  130072080.0  133534923.0  137171659.0
# 2                    Afghanistan    9035043.0    9214083.0    9404406.0
# 3     Africa Western and Central   97630925.0   99706674.0  101854756.0
# 4                         Angola    5231654.0    5301583.0    5354310.0
# ..                           ...          ...          ...          ...
# 261                       Kosovo     984846.0    1011421.0    1036950.0
# 262                  Yemen, Rep.    5532301.0    5655232.0    5782221.0
# 263                 South Africa   16440172.0   16908035.0   17418522.0
# 264                       Zambia    3153729.0    3254086.0    3358099.0
# 265                     Zimbabwe    3809389.0    3930401.0    4055959.0
#
#             1963         1964         1965         1966         1967  \
# ...

# %%
Angola=plot_df.loc[4]
Angola_df=Angola.to_frame().reset_index()
# Out:
#            index           4
# 0   Country Name      Angola
# 1           1960   5231654.0
# 2           1961   5301583.0
# 3           1962   5354310.0
# 4           1963   5408320.0
# ..           ...         ...
# 60          2019  32375632.0
# 61          2020  33451132.0
# 62          2021  34532429.0
# 63          2022  35635029.0
# 64          2023  36749906.0
#
# [65 rows x 2 columns]

# %%
Angola_df.drop([0],axis=0, inplace=True)

# %%
Angola_df.columns=["Year","Population"]

# %%
Angola_df
# Out:
#     Year  Population
# 1   1960   5231654.0
# 2   1961   5301583.0
# 3   1962   5354310.0
# 4   1963   5408320.0
# 5   1964   5464187.0
# ..   ...         ...
# 60  2019  32375632.0
# 61  2020  33451132.0
# 62  2021  34532429.0
# 63  2022  35635029.0
# 64  2023  36749906.0
#
# [64 rows x 2 columns]

# %%
width = 25
height = 8
plt.figure(figsize=(width, height))
sns.lineplot(x=Angola_df["Year"], y=Angola_df["Population"])
# Out:
# <Axes: xlabel='Year', ylabel='Population'>
